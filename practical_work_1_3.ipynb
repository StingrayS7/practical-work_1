# %% [markdown]
# <a href="https://colab.research.google.com/github/StingrayS7/practical-work_1/blob/main/practical_work_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача: создать и обучить модель для предсказания событий выхода из строя оборудования на производстве, опираясь на показатели датчиков.

# %%
import pandas as pd
from requests import get
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
response = get("https://drive.usercontent.google.com/u/0/uc?id=1BmkDUndkHmXgJ_nRIsYp5Kvw0BxeFHzk&export=download")
with open('archive.zip', 'wb') as f:
    f.write(response.content)

# %%
# !unzip -qo "archive.zip" -d ./machine_failure

FILE_PATH = './machine_failure'

# %%
data = pd.read_csv(f'{FILE_PATH}/data.csv')

# %%
# Иформация о столбцах датасета
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   footfall     944 non-null    int64
#  1   tempMode     944 non-null    int64
#  2   AQ           944 non-null    int64
#  3   USS          944 non-null    int64
#  4   CS           944 non-null    int64
#  5   VOC          944 non-null    int64
#  6   RP           944 non-null    int64
#  7   IP           944 non-null    int64
#  8   Temperature  944 non-null    int64
#  9   fail         944 non-null    int64
# dtypes: int64(10)
# memory usage: 73.9 KB

# %% [markdown]
# Описание показателей
#
# *   footfall: Количество людей или объектов, проходящих мимо оборудования
# *   tempMode: Температурный режим оборудования
# *   AQ: Индекс качества воздуха рядом с оборудованием
# *   USS: Данные ультразвукового датчика приближения
# *   CS: данные датчика потребления тока Оборудованием
# *   VOC: Уровень летучих органических соединений рядом с оборудованием
# *   RP: Частота вращения исполнительных элементов оборудования
# *   IP: Входящее давление на оборудование
# *   Temperature: Рабочая температура оборудования
# *   fail: Бинарный (двоичный) индикатор исправности или неисправности оборудования (1 - неисправность, 0 - нет неисправности)

# %%
# Проверка начальных значений датасета
data.head()
# Out:
#    footfall  tempMode  AQ  USS  CS  VOC  RP  IP  Temperature  fail
# 0         0         7   7    1   6    6  36   3            1     1
# 1       190         1   3    3   5    1  20   4            1     0
# 2        31         7   2    2   6    1  24   6            1     0
# 3        83         4   3    4   5    1  28   6            1     0
# 4       640         7   5    6   4    0  68   6            1     0

# %%
# Обработка данных. Поиск нулевых значений в датасете.
miss_val = data.isnull().sum()
print(miss_val.to_markdown())
# Out:
# |             |   0 |
# |:------------|----:|
# | footfall    |   0 |
# | tempMode    |   0 |
# | AQ          |   0 |
# | USS         |   0 |
# | CS          |   0 |
# | VOC         |   0 |
# | RP          |   0 |
# | IP          |   0 |
# | Temperature |   0 |
# | fail        |   0 |

# %%
# Нулевых значений в датасете нет
# Создаем матрицу корреляций для выбора признаков, по которым лучше всего делать предсказывание
corr = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True,)
# Out:
# <Axes: >

# %%
# Лучшими показателями судя по матрице корреляций будут AQ и VOC
fin_data = data[['AQ', 'Temperature', 'fail']]
fin_data.head(20)
# Out:
#     AQ  Temperature  fail
# 0    7            1     1
# 1    3            1     0
# 2    2            1     0
# 3    3            1     0
# 4    5            1     0
# 5    3            1     0
# 6    5            1     0
# 7    5            1     0
# 8    4            1     0
# 9    3            1     0
# 10   3            1     0
# 11   4            1     0
# 12   5            1     1
# 13   4            1     0
# 14   5            1     0
# 15   6            1     0
# 16   4            1     0
# 17   3            1     0
# 18   6            1     1
# 19   2            2     0

# %%
# Подготовим тренировочные и тестовые данные
X = fin_data.drop('fail', axis=1).values
y = fin_data['fail'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
# Создание модели нейронной сети
model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Dense(4, activation='relu'),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ]
)

# Модель 4 слоя, оптимизатор Adam, активаторы relu и sigmoid, функция потерь - бинарная перекрестная энтропия
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Тренируем модель 100 эпох
model.fit(X_train, y_train, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 15ms/step - loss: 2.6482 - accuracy: 0.4172 - val_loss: 2.5211 - val_accuracy: 0.3974
# Epoch 2/100
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0789 - accuracy: 0.4172 - val_loss: 1.9909 - val_accuracy: 0.3974
# Epoch 3/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6517 - accuracy: 0.4172 - val_loss: 1.5875 - val_accuracy: 0.3974
# Epoch 4/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3291 - accuracy: 0.4172 - val_loss: 1.2849 - val_accuracy: 0.3974
# Epoch 5/100
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0992 - accuracy: 0.4172 - val_loss: 1.0662 - val_accuracy: 0.4040
# Epoch 6/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.9396 - accuracy: 0.4288 - val_loss: 0.9231 - val_accuracy: 0.4040
# Epoch 7/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8364 - accuracy: 0.4338 - val_loss: 0.8309 - val_accuracy: 0.4172
# Epoch 8/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7753 - accuracy: 0.4503 - val_loss: 0.7670 - val_accuracy: 0.4238
# Epoch 9/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7334 - accuracy: 0.4603 - val_loss: 0.7294 - val_accuracy: 0.4371
# Epoch 10/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7090 - accuracy: 0.4801 - val_loss: 0.7056 - val_accuracy: 0.4503
# Epoch 11/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.5182 - val_loss: 0.6897 - val_accuracy: 0.5033
# Epoch 12/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6847 - accuracy: 0.5464 - val_loss: 0.6798 - val_accuracy: 0.5497
# Epoch 13/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6788 - accuracy: 0.5811 - val_loss: 0.6728 - val_accuracy: 0.6159
# Epoch 14/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6744 - accuracy: 0.6159 - val_loss: 0.6686 - val_accuracy: 0.6225
# Epoch 15/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6722 - accuracy: 0.6275 - val_loss: 0.6654 - val_accuracy: 0.6291
# Epoch 16/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6706 - accuracy: 0.6126 - val_loss: 0.6635 - val_accuracy: 0.6424
# Epoch 17/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6697 - accuracy: 0.6109 - val_loss: 0.6622 - val_accuracy: 0.6358
# Epoch 18/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6687 - accuracy: 0.5944 - val_loss: 0.6618 - val_accuracy: 0.6026
# Epoch 19/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6680 - accuracy: 0.5944 - val_loss: 0.6611 - val_accuracy: 0.6093
# Epoch 20/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6677 - accuracy: 0.5944 - val_loss: 0.6607 - val_accuracy: 0.6159
# Epoch 21/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6669 - accuracy: 0.5927 - val_loss: 0.6600 - val_accuracy: 0.6093
# Epoch 22/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6665 - accuracy: 0.5944 - val_loss: 0.6599 - val_accuracy: 0.6159
# Epoch 23/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6660 - accuracy: 0.5927 - val_loss: 0.6594 - val_accuracy: 0.6159
# Epoch 24/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6657 - accuracy: 0.5927 - val_loss: 0.6593 - val_accuracy: 0.6159
# Epoch 25/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6653 - accuracy: 0.5927 - val_loss: 0.6592 - val_accuracy: 0.6159
# Epoch 26/100
# 19/19 [==============================] - 0s 10ms/step - loss: 0.6651 - accuracy: 0.5927 - val_loss: 0.6589 - val_accuracy: 0.6159
# Epoch 27/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6647 - accuracy: 0.5944 - val_loss: 0.6586 - val_accuracy: 0.6159
# Epoch 28/100
# 19/19 [==============================] - 0s 10ms/step - loss: 0.6642 - accuracy: 0.5960 - val_loss: 0.6585 - val_accuracy: 0.6159
# Epoch 29/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6639 - accuracy: 0.5960 - val_loss: 0.6578 - val_accuracy: 0.6159
# Epoch 30/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6635 - accuracy: 0.5960 - val_loss: 0.6580 - val_accuracy: 0.6159
# Epoch 31/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6633 - accuracy: 0.5927 - val_loss: 0.6573 - val_accuracy: 0.6159
# Epoch 32/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6629 - accuracy: 0.5944 - val_loss: 0.6576 - val_accuracy: 0.6159
# Epoch 33/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6623 - accuracy: 0.5960 - val_loss: 0.6576 - val_accuracy: 0.6159
# Epoch 34/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6619 - accuracy: 0.5960 - val_loss: 0.6572 - val_accuracy: 0.6159
# Epoch 35/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6615 - accuracy: 0.5960 - val_loss: 0.6569 - val_accuracy: 0.6159
# Epoch 36/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6611 - accuracy: 0.5960 - val_loss: 0.6566 - val_accuracy: 0.6159
# Epoch 37/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6610 - accuracy: 0.5960 - val_loss: 0.6562 - val_accuracy: 0.6159
# Epoch 38/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6604 - accuracy: 0.5960 - val_loss: 0.6557 - val_accuracy: 0.6159
# Epoch 39/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6600 - accuracy: 0.5960 - val_loss: 0.6563 - val_accuracy: 0.6159
# Epoch 40/100
# 19/19 [==============================] - 0s 10ms/step - loss: 0.6601 - accuracy: 0.5944 - val_loss: 0.6549 - val_accuracy: 0.6159
# Epoch 41/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6596 - accuracy: 0.5960 - val_loss: 0.6559 - val_accuracy: 0.6159
# Epoch 42/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6587 - accuracy: 0.5977 - val_loss: 0.6547 - val_accuracy: 0.6159
# Epoch 43/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6583 - accuracy: 0.5927 - val_loss: 0.6539 - val_accuracy: 0.6159
# Epoch 44/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6577 - accuracy: 0.5927 - val_loss: 0.6536 - val_accuracy: 0.6159
# Epoch 45/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6574 - accuracy: 0.5927 - val_loss: 0.6534 - val_accuracy: 0.6159
# Epoch 46/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6568 - accuracy: 0.5960 - val_loss: 0.6537 - val_accuracy: 0.6159
# Epoch 47/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6565 - accuracy: 0.5993 - val_loss: 0.6540 - val_accuracy: 0.6623
# Epoch 48/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6558 - accuracy: 0.6076 - val_loss: 0.6526 - val_accuracy: 0.6159
# Epoch 49/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6554 - accuracy: 0.6076 - val_loss: 0.6521 - val_accuracy: 0.6490
# Epoch 50/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6553 - accuracy: 0.5960 - val_loss: 0.6514 - val_accuracy: 0.6159
# Epoch 51/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6543 - accuracy: 0.6026 - val_loss: 0.6518 - val_accuracy: 0.6556
# Epoch 52/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6540 - accuracy: 0.5960 - val_loss: 0.6510 - val_accuracy: 0.6159
# Epoch 53/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6533 - accuracy: 0.5960 - val_loss: 0.6503 - val_accuracy: 0.6159
# Epoch 54/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6527 - accuracy: 0.6159 - val_loss: 0.6502 - val_accuracy: 0.6623
# Epoch 55/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6524 - accuracy: 0.6275 - val_loss: 0.6505 - val_accuracy: 0.6689
# Epoch 56/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6517 - accuracy: 0.6142 - val_loss: 0.6490 - val_accuracy: 0.6689
# Epoch 57/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6512 - accuracy: 0.6159 - val_loss: 0.6491 - val_accuracy: 0.6689
# Epoch 58/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6500 - accuracy: 0.6358 - val_loss: 0.6483 - val_accuracy: 0.6689
# Epoch 59/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6493 - accuracy: 0.6175 - val_loss: 0.6472 - val_accuracy: 0.6689
# Epoch 60/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6483 - accuracy: 0.6225 - val_loss: 0.6468 - val_accuracy: 0.6689
# Epoch 61/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6471 - accuracy: 0.6159 - val_loss: 0.6458 - val_accuracy: 0.6689
# Epoch 62/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6458 - accuracy: 0.6291 - val_loss: 0.6454 - val_accuracy: 0.6623
# Epoch 63/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6433 - accuracy: 0.6490 - val_loss: 0.6439 - val_accuracy: 0.6623
# Epoch 64/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6411 - accuracy: 0.6258 - val_loss: 0.6414 - val_accuracy: 0.6490
# Epoch 65/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6369 - accuracy: 0.6755 - val_loss: 0.6391 - val_accuracy: 0.7285
# Epoch 66/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6293 - accuracy: 0.7682 - val_loss: 0.6300 - val_accuracy: 0.7616
# Epoch 67/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6164 - accuracy: 0.7566 - val_loss: 0.6131 - val_accuracy: 0.7881
# Epoch 68/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6034 - accuracy: 0.7947 - val_loss: 0.6043 - val_accuracy: 0.7947
# Epoch 69/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5940 - accuracy: 0.7980 - val_loss: 0.5978 - val_accuracy: 0.7881
# Epoch 70/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5858 - accuracy: 0.7930 - val_loss: 0.5908 - val_accuracy: 0.7947
# Epoch 71/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5781 - accuracy: 0.7947 - val_loss: 0.5836 - val_accuracy: 0.7947
# Epoch 72/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5676 - accuracy: 0.7765 - val_loss: 0.5672 - val_accuracy: 0.7947
# Epoch 73/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5507 - accuracy: 0.7897 - val_loss: 0.5527 - val_accuracy: 0.7947
# Epoch 74/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5442 - accuracy: 0.7864 - val_loss: 0.5459 - val_accuracy: 0.7947
# Epoch 75/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5372 - accuracy: 0.7815 - val_loss: 0.5432 - val_accuracy: 0.7947
# Epoch 76/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5333 - accuracy: 0.7848 - val_loss: 0.5360 - val_accuracy: 0.7748
# Epoch 77/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5268 - accuracy: 0.7964 - val_loss: 0.5357 - val_accuracy: 0.7947
# Epoch 78/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5255 - accuracy: 0.7930 - val_loss: 0.5309 - val_accuracy: 0.7947
# Epoch 79/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5221 - accuracy: 0.7848 - val_loss: 0.5268 - val_accuracy: 0.7947
# Epoch 80/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5188 - accuracy: 0.7980 - val_loss: 0.5225 - val_accuracy: 0.7748
# Epoch 81/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5147 - accuracy: 0.7831 - val_loss: 0.5221 - val_accuracy: 0.7881
# Epoch 82/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5111 - accuracy: 0.7947 - val_loss: 0.5205 - val_accuracy: 0.7881
# Epoch 83/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5093 - accuracy: 0.7980 - val_loss: 0.5157 - val_accuracy: 0.7881
# Epoch 84/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5092 - accuracy: 0.7815 - val_loss: 0.5202 - val_accuracy: 0.7881
# Epoch 85/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7964 - val_loss: 0.5153 - val_accuracy: 0.7881
# Epoch 86/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5024 - accuracy: 0.7897 - val_loss: 0.5106 - val_accuracy: 0.7881
# Epoch 87/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4992 - accuracy: 0.7980 - val_loss: 0.5147 - val_accuracy: 0.7881
# Epoch 88/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4994 - accuracy: 0.7964 - val_loss: 0.5136 - val_accuracy: 0.7881
# Epoch 89/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4977 - accuracy: 0.7881 - val_loss: 0.5040 - val_accuracy: 0.7748
# Epoch 90/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4956 - accuracy: 0.7980 - val_loss: 0.5070 - val_accuracy: 0.7881
# Epoch 91/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4928 - accuracy: 0.7980 - val_loss: 0.5048 - val_accuracy: 0.7881
# Epoch 92/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4935 - accuracy: 0.7881 - val_loss: 0.5102 - val_accuracy: 0.7881
# Epoch 93/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4941 - accuracy: 0.7980 - val_loss: 0.5053 - val_accuracy: 0.7881
# Epoch 94/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4877 - accuracy: 0.7980 - val_loss: 0.5072 - val_accuracy: 0.7881
# Epoch 95/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4860 - accuracy: 0.7947 - val_loss: 0.4965 - val_accuracy: 0.7881
# Epoch 96/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4855 - accuracy: 0.7947 - val_loss: 0.4974 - val_accuracy: 0.7881
# Epoch 97/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4840 - accuracy: 0.7980 - val_loss: 0.4983 - val_accuracy: 0.7881
# Epoch 98/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4813 - accuracy: 0.7980 - val_loss: 0.4984 - val_accuracy: 0.7881
# Epoch 99/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4822 - accuracy: 0.7980 - val_loss: 0.4933 - val_accuracy: 0.7881
# Epoch 100/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4792 - accuracy: 0.7980 - val_loss: 0.4973 - val_accuracy: 0.7881

# %%
# Проверяем модель на тестовых данных
res = model.evaluate(X_test, y_test)
print('Тестовая ошибка, тестовая точность:', res)
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4977 - accuracy: 0.7513
# Тестовая ошибка, тестовая точность: [0.49772515892982483, 0.7513227462768555]

# %% [markdown]
# При обучении модели на данном датасете можно наблюдать высокий показатель обучающей и валидационной ошибок, а так же недостаточную точность модели. Возможное решение: использование более крупного датасета.
